# %%
# Import required libraries
import pandas as pd
import numpy as np 
import tensorflow.keras as keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, BatchNormalization
from keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler ,MinMaxScaler
from sklearn import preprocessing

# %%
#Data preprocessing: It involves loading CSV data, label encoding, feature scaling and data split into training and test set.
# loading CSV data
data = pd.read_csv('mycsv.csv') 
print(data.shape)
data.describe()
data.head()
# Out:
# (500, 29)
#             filename  zcr_mean   zcr_std  spectral_centroid  \
# 0  country.00000.wav  0.106455  0.027774        2797.844810
# 1  country.00001.wav  0.126123  0.012764        2938.155358
# 2  country.00002.wav  0.073536  0.024575        2308.673365
# 3  country.00003.wav  0.102038  0.023706        2174.033869
# 4  country.00004.wav  0.123667  0.020162        2966.086095
#
#    mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 0            6221.176656           1340.244094         2847.551887
# 1            6279.551665            791.336435         2839.657689
# 2            5190.053453           1328.811306         2618.607096
# 3            4347.882042           1605.860648         2280.888606
# 4            6349.153274           1086.216892         2848.106749
#
#    chroma_deviation_mean       mfcc1      mfcc2  ...    mfcc12    mfcc13  \
# 0               0.384027  -23.066956  70.261658  ...  2.089481 -3.375139
# 1               0.414032   -7.939365  62.723667  ...  6.541569  0.736442
# 2               0.297045 -120.270332  79.230972  ...  0.227432 -6.813057
# 3               0.376894  -57.736473  95.770218  ...  2.432669  1.996366
# 4               0.382781  -20.747871  62.953930  ...  7.521360 -0.983494
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  \
# 0  5.138017 -0.188453  0.375013  0.615662  4.062637  0.909476  4.095611
# 1 -1.773687  0.848610  2.983558 -2.764677  2.824268 -1.738780  0.974067
# 2  1.617267 -1.786316 -0.700590 -4.772855 -0.286400 -5.357112 -1.965473
# 3 -1.285581  1.356409  4.421022 -6.525970 -0.034700 -1.414051 -3.078825
# 4  4.021631 -0.659697 -0.061315 -0.166441  0.241561 -5.440013  1.827359
#
#      genre
# 0  country
# 1  country
# 2  country
# 3  country
# 4  country
#
# [5 rows x 29 columns]

# %%
# Dropping unnecessary columns
dataset = data.drop(['filename'],axis=1)
dataset.head()
# Out:
#    zcr_mean   zcr_std  spectral_centroid  mean_spectral_rolloff  \
# 0  0.106455  0.027774        2797.844810            6221.176656
# 1  0.126123  0.012764        2938.155358            6279.551665
# 2  0.073536  0.024575        2308.673365            5190.053453
# 3  0.102038  0.023706        2174.033869            4347.882042
# 4  0.123667  0.020162        2966.086095            6349.153274
#
#    std_spectral_rolloff  spectral_bandwidth  chroma_deviation_mean  \
# 0           1340.244094         2847.551887               0.384027
# 1            791.336435         2839.657689               0.414032
# 2           1328.811306         2618.607096               0.297045
# 3           1605.860648         2280.888606               0.376894
# 4           1086.216892         2848.106749               0.382781
#
#         mfcc1      mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14  \
# 0  -23.066956  70.261658   3.813589  ...  2.089481 -3.375139  5.138017
# 1   -7.939365  62.723667  -1.456931  ...  6.541569  0.736442 -1.773687
# 2 -120.270332  79.230972   5.233848  ...  0.227432 -6.813057  1.617267
# 3  -57.736473  95.770218 -10.117165  ...  2.432669  1.996366 -1.285581
# 4  -20.747871  62.953930   2.302431  ...  7.521360 -0.983494  4.021631
#
#      mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20    genre
# 0 -0.188453  0.375013  0.615662  4.062637  0.909476  4.095611  country
# 1  0.848610  2.983558 -2.764677  2.824268 -1.738780  0.974067  country
# 2 -1.786316 -0.700590 -4.772855 -0.286400 -5.357112 -1.965473  country
# 3  1.356409  4.421022 -6.525970 -0.034700 -1.414051 -3.078825  country
# 4 -0.659697 -0.061315 -0.166441  0.241561 -5.440013  1.827359  country
#
# [5 rows x 28 columns]

# %%
# Label encoding
encode = LabelEncoder().fit(dataset.iloc[:,-1])
y= LabelEncoder().fit_transform(dataset.iloc[:,-1]) #feature scaling
y.shape
# Out:
# (500,)

# %%
X = StandardScaler().fit_transform(np.array(dataset.iloc[:, :-8], dtype = float))
X.shape
# Out:
# (500, 20)

# %%
#Creating training and testing data set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (350, 20) (350,)
# Test set: (150, 20) (150,)

# %%
# defining our regression model 
n_cols = dataset.iloc[:, :-8].shape[1]
def regression_model_1():
    # structure of our model
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(n_cols,)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu',))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(5,activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               5376
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 50,693
# Trainable params: 49,733
# Non-trainable params: 960
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=10, 
                                            verbose=1, 
                                            )
Callbacks = [earlystop, learning_rate_reduction]

# %%
#build the model
model_1 = regression_model_1()

#fit the model
model_1.fit(X_train,y_train,epochs=100,batch_size=150)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 3s 16ms/step - loss: 2.3310 - accuracy: 0.1829
# Epoch 2/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9962 - accuracy: 0.2543
# Epoch 3/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8487 - accuracy: 0.2971
# Epoch 4/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6511 - accuracy: 0.3571
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.6034 - accuracy: 0.3914
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.4496 - accuracy: 0.4114
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.3569 - accuracy: 0.3971
# Epoch 8/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.3996 - accuracy: 0.4571
# Epoch 9/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.3632 - accuracy: 0.4571
# Epoch 10/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2395 - accuracy: 0.5086
# Epoch 11/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2107 - accuracy: 0.5143
# Epoch 12/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.1459 - accuracy: 0.5314
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.1799 - accuracy: 0.5200
# Epoch 14/100
# 3/3 [==============================] - 0s 10ms/step - loss: 1.1781 - accuracy: 0.5229
# Epoch 15/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0876 - accuracy: 0.5429
# Epoch 16/100
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0746 - accuracy: 0.5457
# Epoch 17/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.1028 - accuracy: 0.5543
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.0712 - accuracy: 0.5457
# Epoch 19/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0759 - accuracy: 0.6000
# Epoch 20/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.0247 - accuracy: 0.5914
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0176 - accuracy: 0.5971
# Epoch 22/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.9819 - accuracy: 0.6029
# Epoch 23/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.9789 - accuracy: 0.6114
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8603 - accuracy: 0.6829
# Epoch 25/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.9017 - accuracy: 0.6657
# Epoch 26/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8808 - accuracy: 0.6114
# Epoch 27/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8989 - accuracy: 0.6314
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8769 - accuracy: 0.6514
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8121 - accuracy: 0.6800
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8445 - accuracy: 0.6686
# Epoch 31/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8678 - accuracy: 0.6629
# Epoch 32/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8626 - accuracy: 0.6657
# Epoch 33/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8985 - accuracy: 0.6543
# Epoch 34/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.8696 - accuracy: 0.6714
# Epoch 35/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7560 - accuracy: 0.7200
# Epoch 36/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7317 - accuracy: 0.7200
# Epoch 37/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8010 - accuracy: 0.6914
# Epoch 38/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7231 - accuracy: 0.7314
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7264 - accuracy: 0.7600
# Epoch 40/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6682 - accuracy: 0.7629
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7614 - accuracy: 0.6886
# Epoch 42/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7042 - accuracy: 0.7514
# Epoch 43/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6702 - accuracy: 0.7629
# Epoch 44/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7111 - accuracy: 0.7286
# Epoch 45/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6605 - accuracy: 0.7714
# Epoch 46/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6629 - accuracy: 0.7286
# Epoch 47/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6068 - accuracy: 0.7771
# Epoch 48/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6325 - accuracy: 0.7743
# Epoch 49/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6221 - accuracy: 0.7657
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6329 - accuracy: 0.7743
# Epoch 51/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6324 - accuracy: 0.7514
# Epoch 52/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6330 - accuracy: 0.7714
# Epoch 53/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5911 - accuracy: 0.8086
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5995 - accuracy: 0.7600
# Epoch 55/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5302 - accuracy: 0.7857
# Epoch 56/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5532 - accuracy: 0.7800
# Epoch 57/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5688 - accuracy: 0.7971
# Epoch 58/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5433 - accuracy: 0.8143
# Epoch 59/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5052 - accuracy: 0.8171
# Epoch 60/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5412 - accuracy: 0.8029
# Epoch 61/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4780 - accuracy: 0.8314
# Epoch 62/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5022 - accuracy: 0.8171
# Epoch 63/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4940 - accuracy: 0.8286
# Epoch 64/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4808 - accuracy: 0.8400
# Epoch 65/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5039 - accuracy: 0.8171
# Epoch 66/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4985 - accuracy: 0.8143
# Epoch 67/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5057 - accuracy: 0.8229
# Epoch 68/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4955 - accuracy: 0.8314
# Epoch 69/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4751 - accuracy: 0.8400
# Epoch 70/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4486 - accuracy: 0.8457
# Epoch 71/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4521 - accuracy: 0.8400
# Epoch 72/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4242 - accuracy: 0.8571
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4330 - accuracy: 0.8371
# Epoch 74/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4712 - accuracy: 0.8314
# Epoch 75/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4161 - accuracy: 0.8571
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3774 - accuracy: 0.8743
# Epoch 77/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3972 - accuracy: 0.8600
# Epoch 78/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3774 - accuracy: 0.8543
# Epoch 79/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4039 - accuracy: 0.8571
# Epoch 80/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3679 - accuracy: 0.8629
# Epoch 81/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4068 - accuracy: 0.8657
# Epoch 82/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3926 - accuracy: 0.8429
# Epoch 83/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3793 - accuracy: 0.8743
# Epoch 84/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3688 - accuracy: 0.8686
# Epoch 85/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3410 - accuracy: 0.8943
# Epoch 86/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3338 - accuracy: 0.8743
# Epoch 87/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3234 - accuracy: 0.8800
# Epoch 88/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3307 - accuracy: 0.8886
# Epoch 89/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3553 - accuracy: 0.8686
# Epoch 90/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3181 - accuracy: 0.8971
# Epoch 91/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3239 - accuracy: 0.8971
# Epoch 92/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3550 - accuracy: 0.8743
# Epoch 93/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3130 - accuracy: 0.8857
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3192 - accuracy: 0.8857
# Epoch 95/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2765 - accuracy: 0.9171
# Epoch 96/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3402 - accuracy: 0.8886
# Epoch 97/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3199 - accuracy: 0.9000
# Epoch 98/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2952 - accuracy: 0.8971
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2842 - accuracy: 0.9057
# Epoch 100/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2641 - accuracy: 0.9114

# %%
model_1.save('Keras_reg_30sec_5.h5')

# %%
model = load_model('Keras_reg_30sec_5.h5')
score = model.evaluate(X_test,y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# accuracy: 66.00%

# %%
#predictions = model.predict_classes(X_test)
predict_x=model.predict(X_test) 
predictions=np.argmax(predict_x,axis=1)
print(predictions)
print(y_test)
# Out:
# [2 0 3 1 1 0 0 1 3 3 1 1 4 0 2 1 0 0 4 4 4 4 0 0 0 4 4 4 1 3 4 3 4 1 0 3 3
#  4 1 0 0 0 4 2 0 0 0 2 1 0 0 1 1 4 4 0 1 0 3 3 4 3 1 0 0 4 0 4 2 3 2 0 2 2
#  3 3 3 0 1 4 1 0 1 1 4 0 4 3 3 2 3 4 3 3 1 0 0 4 1 1 2 0 0 4 3 0 3 2 3 4 1
#  4 3 0 4 3 2 3 1 0 2 1 3 1 1 2 4 2 0 4 0 1 4 2 1 0 1 0 0 2 4 2 4 0 2 2 0 2
#  2 4]
# [3 0 3 1 1 3 3 1 0 4 0 1 4 0 3 3 4 0 3 4 4 4 2 3 0 4 4 2 1 3 4 3 4 1 0 3 4
#  0 2 0 3 0 4 1 0 0 0 0 4 0 0 1 1 4 1 0 1 0 2 0 4 2 3 4 0 0 4 0 2 3 3 3 2 2
#  3 3 2 0 4 4 1 0 4 1 3 0 1 4 3 2 3 4 3 3 4 3 0 0 4 0 2 4 0 3 3 0 3 2 3 1 1
#  4 3 0 4 2 2 2 1 0 2 1 3 1 2 2 4 2 1 3 0 1 4 2 1 0 1 0 0 2 0 2 4 0 2 2 0 2
#  2 4]

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(y_test,predictions)
print(cf_matrix)
# Out:
# [[29  2  1  2  5]
#  [ 1 18  1  0  3]
#  [ 1  2 17  5  1]
#  [ 6  2  3 16  4]
#  [ 4  5  0  3 19]]

# %%
import seaborn as sns
# %matplotlib inline
classes=['country', 'disco', 'hiphop', 'reggae', 'rock']
sns.heatmap(cf_matrix, annot=True , cmap='Blues',xticklabels=classes,yticklabels=classes)
# Out:
# <AxesSubplot:>
