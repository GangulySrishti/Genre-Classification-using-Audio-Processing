# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Music_Features_dataset(2).csv')
data2 = pd.read_csv('Music_Features_dataset(3).csv')

# %%
data.head()
# Out:
#           filename  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00000.wav     0.349943  0.130225        1784.420446
# 1  blues.00001.wav     0.340983  0.095918        1529.835316
# 2  blues.00002.wav     0.363603  0.175573        1552.481958
# 3  blues.00003.wav     0.404779  0.141191        1070.119953
# 4  blues.00004.wav     0.308590  0.091563        1835.494603
#
#    spectral_bandwidth  spectral_rolloff  zero_crossing_rate       mfcc1  \
# 0         2002.650192       3806.485316            0.083066 -113.596742
# 1         2038.617579       3548.820207            0.056044 -207.556796
# 2         1747.165985       3040.514948            0.076301  -90.754394
# 3         1596.333948       2185.028454            0.033309 -199.431144
# 4         1748.362448       3580.945013            0.101500 -160.266031
#
#         mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14    mfcc15  \
# 0  121.557302 -19.158825  ...  8.810668 -3.667367  5.751690 -5.162761
# ...

# %%
dataset = data.drop(['filename','mfcc14','mfcc15','mfcc16','mfcc17','mfcc18','mfcc19','mfcc20'],axis=1)
dataset2 = data.drop(['filename','mfcc14','mfcc15','mfcc16','mfcc17','mfcc18','mfcc19','mfcc20'],axis=1)
dataset.head()
# Out:
#    chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# 0     0.349943  0.130225        1784.420446         2002.650192
# 1     0.340983  0.095918        1529.835316         2038.617579
# 2     0.363603  0.175573        1552.481958         1747.165985
# 3     0.404779  0.141191        1070.119953         1596.333948
# 4     0.308590  0.091563        1835.494603         1748.362448
#
#    spectral_rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  \
# 0       3806.485316            0.083066 -113.596742  121.557302 -19.158825
# 1       3548.820207            0.056044 -207.556796  124.006717   8.930562
# 2       3040.514948            0.076301  -90.754394  140.459907 -29.109965
# 3       2185.028454            0.033309 -199.431144  150.099218   5.647594
# 4       3580.945013            0.101500 -160.266031  126.198800 -35.605448
#
#        mfcc4      mfcc5      mfcc6      mfcc7      mfcc8      mfcc9  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import preprocessing

# %%
y = LabelEncoder().fit_transform(dataset.iloc[:,-1])
y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-46b13789e554> in <module>
# ----> 1 y = LabelEncoder().fit_transform(dataset.iloc[:,-1])
#       2 y.shape
#
# NameError: name 'dataset' is not defined

# %%
X = StandardScaler().fit_transform(np.array(dataset.iloc[:, :-1], dtype = float))
X.shape
# Out:
# (999, 19)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (699, 19) (699,)
# Test set: (300, 19) (300,)

# %%
import tensorflow.keras as keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
# defining our regression model (2)
n_cols = dataset.iloc[:, :-1].shape[1]
def regression_model_2():
    # structure of our model
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(n_cols,)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu',))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(10,activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=25)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=20, 
                                            verbose=1, 
                                            )
Callbacks = [earlystop, learning_rate_reduction]

# %%
# build the model
# model_2 = regression_model_2()

# fit the model
# model_2.fit(X_train,y_train, callbacks=Callbacks , validation_data=(X_test,y_test) ,epochs=200,batch_size=150)

# %%
# model_2.save('MGD_reg_2.h5')

# %%
from keras.models import load_model
# build the model
model_3 = load_model('MGD_reg_2.h5')

# compile the model
model_3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#evaluate the model
score=model_3.evaluate(X_test,y_test,verbose=1)
print("%s:  %.2f%%" % (model_3.metrics_names[1],score[1]*100))
# Out:
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 300/300 [==============================] - 1s 4ms/step
# accuracy:  73.33%

# %%
d = pd.read_csv('Music_Features_dataset(2).csv')

# %%
d.iloc[0]
# Out:
# filename              blues.00000.wav
# chroma_stft                  0.349943
# rmse                         0.130225
# spectral_centroid             1784.42
# spectral_bandwidth            2002.65
# spectral_rolloff              3806.49
# zero_crossing_rate          0.0830664
# mfcc1                        -113.597
# mfcc2                         121.557
# mfcc3                        -19.1588
# mfcc4                          42.351
# mfcc5                        -6.37646
# mfcc6                         18.6189
# mfcc7                        -13.6979
# mfcc8                         15.3446
# mfcc9                        -12.2853
# mfcc10                        10.9805
# mfcc11                       -8.32432
# mfcc12                        8.81067
# mfcc13                       -3.66737
# mfcc14                        5.75169
# mfcc15                       -5.16276
# mfcc16                       0.750947
# mfcc17                       -1.69194
# mfcc18                      -0.409954
# ...
